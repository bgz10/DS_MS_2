# %%
#importing necessery libraries for future analysis of the dataset
import numpy as np
import pandas as pd

# %%
#using pandas library and 'read_csv' function to read csv file 
income=pd.read_csv('income.csv')
#examing head of csv file 
income.head()
# Out:
#                                                 Fact Fact Note  \
# 0       Population estimates, July 1, 2018,  (V2018)       NaN
# 1  Population estimates base, April 1, 2010,  (V2...       NaN
# 2  Population, percent change - April 1, 2010 (es...       NaN
# 3                  Population, Census, April 1, 2010       NaN
# 4                     Persons under 5 years, percent       NaN
#
#   New York city, New York  Value Note for New York city, New York  \
# 0               8,398,748                                     NaN
# 1               8,174,988                                     NaN
# 2                    2.7%                                     NaN
# 3               8,175,133                                     NaN
# 4                    6.5%                                     NaN
#
#   Bronx County (Bronx Borough), New York  \
# 0                              1,432,132
# 1                              1,384,603
# 2                                   3.4%
# ...

# %%
#checking amount of rows in given dataset to understand the size we are working with
len(income)

# %%
#after looking at the head of the dataset we already were able to notice some NaN values, therefore need to examine missing values further before continuing with analysis

#looking to find out first what columns have null values
#using 'sum' function will show us how many nulls are found in each column in dataset
income.isnull().sum()

# %%
#dropping columns that are not significant or could be unethical to use for our future data exploration and predictions
income.drop(['Fact Note','Value Note for New York city, New York','Value Note for Bronx County (Bronx Borough), New York','Value Note for Kings County (Brooklyn Borough), New York','Value Note for New York County (Manhattan Borough), New York','Value Note for Queens County (Queens Borough), New York','Value Note for Richmond County (Staten Island Borough), New York'], axis=1, inplace=True)
#examing the changes
#incomehead()

# %%
income
